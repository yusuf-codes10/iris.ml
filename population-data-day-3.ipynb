# %% [markdown]
# First is importing the necessary tools and packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !find ../input/
# Out:
# ../input/
# ../input/datasets
# ../input/datasets/organizations
# ../input/datasets/organizations/uciml
# ../input/datasets/organizations/uciml/iris
# ../input/datasets/organizations/uciml/iris/Iris.csv
# ../input/datasets/organizations/uciml/iris/database.sqlite
# ../input/datasets/youcefcopy
# ../input/datasets/youcefcopy/world-popilation
# ../input/datasets/youcefcopy/world-popilation/world_population.csv

# %%
df = pd.read_csv('../input/datasets/youcefcopy/world-popilation/world_population.csv')
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' %x) # this is how we change how many decimal points

# %%
df.info() # Gives you a quick structural overview of your dataset.such as the columns and datatypes, rows number and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe() # Shows statistics for numeric columns. std, min max....
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum() # Counts missing values per column.
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()  # Counts unique values in each column.
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by= 'Area (km²)', ascending=False).head(10) # sort by lowest to highest in 2022 popuation
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 171     9  RUS         Russia            Moscow         Europe
# 35     39  CAN         Canada            Ottawa  North America
# 41      1  CHN          China           Beijing           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
# 11     55  AUS      Australia          Canberra        Oceania
# 92      2  IND          India         New Delhi           Asia
# 8      33  ARG      Argentina      Buenos Aires  South America
# 105    66  KAZ     Kazakhstan         Nursultan           Asia
# 2      34  DZA        Algeria           Algiers         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 171     144713314.00     145617329.00     144668389.00     143242599.00
# 35       38454327.00      37888705.00      35732126.00      33963412.00
# ...

# %% [markdown]
# If two columns have correlation close to 1, they contain almost the same information.
#
# This is called:
#
# multicollinearity
#
# Example:
#
# Population 2022
# Population 2020
# Population 2015
#
# A model might only need one of them.
#
# Because the others add redundant information.

# %%
df.corr(numeric_only=True) # correlation
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)  # heatmap and the thing to heatmap

plt.rcParams['figure.figsize'] = (20, 7) # soze
plt.show()   # show the graph

# %% [markdown]
# Day 2: Grouping

# %%
df.groupby('Continent').mean(numeric_only=True) # like sql group by | always use numeric_only
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Asia           77.56      96327387.31      94955134.37      89165003.64
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18898197.31      14598365.95      11376964.52
# Asia               89087770.00      80580835.11      48639995.33
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
# ...

# %% [markdown]
# find Oceaniana

# %%
df[df['Continent'].str.contains('Oceania')].sort_values(by='2022 Population', ascending=False) # find the continent ceanea and sort by 2022 population
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 11     55  AUS                 Australia      Canberra   Oceania
# 160    93  PNG          Papua New Guinea  Port Moresby   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 191   166  SLB           Solomon Islands       Honiara   Oceania
# 225   181  VUT                   Vanuatu     Port-Vila   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 179   188  WSM                     Samoa          Apia   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 210   197  TON                     Tonga    Nuku‘alofa   Oceania
# ...

# %%
df2.transpose() # flip
# Out:
# Continent                          Asia  South America      Africa  \
# Rank                              77.56          97.57       92.16
# 2022 Population             96327387.31    31201186.29 25455879.68
# 2020 Population             94955134.37    30823574.50 23871435.26
# 2015 Population             89165003.64    29509599.71 21419703.57
# 2010 Population             89087770.00    26789395.54 18898197.31
# 2000 Population             80580835.11    25015888.69 14598365.95
# 1990 Population             48639995.33    21224743.93 11376964.52
# 1980 Population             40278333.33    17270643.29  8586031.98
# 1970 Population             43839877.83    13781939.71  6567175.27
# Area (km²)                    642762.82     1301302.85   537879.30
# Density (per km²)               1025.02          20.97      126.41
# Growth Rate                        1.01           1.01        1.02
# World Population Percentage        1.18           0.39        0.31
#
# ...

# %%
df2 = df.groupby('Continent').mean(numeric_only=True).sort_values(by='2022 Population', ascending=False)
df2.plot()
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# we wanna represant the clolumns of population only

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df2 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean(numeric_only=True).sort_values(by='2022 Population', ascending=False)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df3 = df2.transpose()

# %% [markdown]
# df2.plot()

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df4 = df[df['Country'] == 'Algeria'].sort_values(by='2022 Population', ascending=False) # find the continent ceanea and sort by 2022 population
df4
# Out:
#    Rank CCA3  Country  Capital Continent  2022 Population  2020 Population  \
# 2    34  DZA  Algeria  Algiers    Africa      44903225.00      43451666.00
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 2      39543154.00      35856344.00      30774621.00      25518074.00
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 2      18739378.00      13795915.00  2381741.00              18.85
#
#    Growth Rate  World Population Percentage
# 2         1.02                         0.56

# %%
pop_cols = [
'1970 Population','1980 Population','1990 Population','2000 Population',
'2010 Population','2015 Population','2020 Population','2022 Population'
]

# %% [markdown]
# plting algeria populaiton

# %%
df4[pop_cols].T.plot()
# plt.show()
# Out:
# <Axes: >

# %%
Day 3:

# %%
# Boxplots for outliers
df.boxplot()
# Out:
# <Axes: >
