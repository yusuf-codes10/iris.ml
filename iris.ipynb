# %% [markdown]
# <a href="https://colab.research.google.com/github/yusuf-codes10/iris.ml/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler

# %%
import seaborn as sns

# %% [markdown]
# Now we define the dataset

# %%
labels = ['spaleLength', 'sapleWidth', 'petalLength', 'petalWidth', 'class']
df = pd.read_csv('iris.data', names=labels)
df.head(20)
# Out:
#     spaleLength  sapleWidth  petalLength  petalWidth        class
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.4         0.2  Iris-setosa
# 9           4.9         3.1          1.5         0.1  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# ...

# %% [markdown]
# 🌱 Stage 1: Understand Your Data (Do This First)

# %%
df.shape # rows/columns
# Out:
# (150, 5)

# %%
df.dtypes # data types
# Out:
# spaleLength    float64
# sapleWidth     float64
# petalLength    float64
# petalWidth     float64
# class           object
# dtype: object

# %%
df.describe()   # stats: mean, min, max, std
# Out:
#        spaleLength  sapleWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.isnull().sum() # find the missing values
# Out:
# spaleLength    0
# sapleWidth     0
# petalLength    0
# petalWidth     0
# class          0
# dtype: int64

# %%
df['class'].value_counts()  # how many of each flower type?
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
plt.plot(df['sapleWidth'])
plt.plot(df['spaleLength'])
plt.plot(df['petalWidth'])
plt.plot(df['petalLength'])

# %%
sns.pairplot(df, hue='class')
plt.show()

# %% [markdown]
# Let's attempt to draw some histograms

# %%
for col in labels[:-1]:
  plt.hist(df[df['class'] == 'Iris-setosa'][col], color='blue', density=True, alpha=0.8)
  plt.hist(df[df['class'] == 'Iris-virginica'][col], color='pink', density=True, alpha=0.8)
  plt.hist(df[df['class'] == 'Iris-versicolor'][col], color='green', density=True, alpha=0.8)
  plt.title('Iris')
  plt.xlabel(col)
  plt.ylabel('Probability')
  plt.legend(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'])
  plt.show()

# %% [markdown]
# # Split the dataset

# %% [markdown]
# ## 1- sclale dataset function

# %%
def scale_dataset(dataframe, oversample=False):
  x = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values


  if oversample:
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x, y)

  scaler = StandardScaler()
  x = scaler.fit_transform(x)
  data = np.hstack((x, np.reshape(y, (-1, 1))))
  return data, x, y

# %% [markdown]
# ## Split & Scale

# %%
# Always split from the ORIGINAL df — never from train/valid/test
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)

train_df = df_shuffled[:int(0.6*len(df_shuffled))]
valid_df = df_shuffled[int(0.6*len(df_shuffled)):int(0.8*len(df_shuffled))]
test_df  = df_shuffled[int(0.8*len(df_shuffled)):]

train, X_train, y_train = scale_dataset(train_df, oversample=True)
valid, X_valid, y_valid = scale_dataset(valid_df, oversample=False)
test,  X_test,  y_test  = scale_dataset(test_df,  oversample=False)
